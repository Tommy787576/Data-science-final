# %%
#for google colab, ignore this
# %cd /content/drive/MyDrive/DataScience

# %%
import numpy as np
import time
import datetime

def print_t(start_t):
  current_t = time.time() - start_t
  current_t = str(datetime.timedelta(seconds=current_t))[:-7]
  print("[{}] ".format(current_t))
print("build")

# %%
import pandas as pd

s_t = time.time()
#df_train = pd.read_csv("./data/train_ver2.csv")
df_train = pd.read_csv("./data/processed/ver1_1.csv")
print_t(s_t)

# %%
df_train

# %%
#split into train set/dev set

# %%
df1 = df_train[df_train['fecha_dato'] >= 1]
df1

# %%
s_t = time.time()
df1.to_csv("./data/processed/dev.csv", index=False)
print_t(s_t)
# Out:
# [0:00:15]

# %%
df2 = df_train[df_train['fecha_dato'] < 1]
df2

# %%
s_t = time.time()
df2.to_csv("./data/processed/train.csv", index=False)
print_t(s_t)
# Out:
# [0:03:29]

# %%
#print data, get som info

# %%
df_train.isnull().sum()

# %%
for col in df_train.columns:
  print("========================{}=========================".format(col))
  print(df_train[col].value_counts())
# Out:
# ========================fecha_dato=========================
# 1.000000    931453
# 0.943431    928274
# 0.886861    925076
# 0.830292    920904
# 0.773723    916269
# 0.729927    912021
# 0.673358    906109
# 0.616788    892251
# 0.560219    865440
# 0.503650    843201
# 0.447080    829817
# 0.390511    632110
# 0.333942    631957
# 0.277372    630367
# 0.220803    629209
# 0.164234    627394
# 0.107664    625457
# Name: fecha_dato, dtype: int64
# ========================ncodpers=========================
# 32752      17
# 1273696    17
# 1224536    17
# 1199940    17
# 1208128    17
#            ..
# 1549150     1
# 1543059     1
# 1535935     1
# 1551255     1
# 1489485     1
# Name: ncodpers, Length: 956645, dtype: int64
# ========================ind_empleado=========================
# 0    13638711
# 2        3566
# 3        2523
# 1        2492
# 4          17
# Name: ind_empleado, dtype: int64
# ========================pais_residencia=========================
# 0      13581444
# ...

# %%
#drop unnecessary data

# %%
df_train.drop(columns=['ult_fec_cli_1t', 'conyuemp'], inplace=True)

# %%
df_train.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1'], inplace=True)

# %%
df_train.drop(columns=['tipodom'], inplace=True)

# %%
df_train.drop(columns=['nomprov'], inplace=True)

# %%
#data preprocess

# %%
import numpy as np
feature = 'fecha_dato'
s_t = time.time()
"""
fea = []
#lenght:13647309
_c = 0
for e in df_train[feature]:
  y = int(e[:4])
  m = int(e[5:7])
  d = int(e[-2:])
  
  #print(y, m, d)
  #if _c == 200:
    #break
  days = 365*(y-2015)+31*(m)+d
  #if days not in fea:
    #fea.append(days)
  fea.append(days)
  _c += 1
fea = np.array(fea)
print(np.max(fea, axis=0)) #548
print(np.min(fea, axis=0)) #59
fea = fea / np.max(fea, axis=0)
"""
#"""
_c = 0
for e in df_train[feature]:
  y = int(e[:4])
  m = int(e[5:7])
  d = int(e[-2:])
  days = 365*(y-2015)+31*(m)+d
  days = days / 548
  df_train.at[_c, feature] = days
  _c += 1
print_t(s_t)
print("finish")
#"""
# Out:
# finish

# %%
s_t = time.time()
feature = 'ind_empleado'
"""
ind = {}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = _c
    _c += 1
print(ind)
"""
def get_onehot(size, value):
  emb = np.zeros(size)
  emb[value] = 1
  return emb
#"""
map = {'N':0, 'A':1, 'B':2, 'F':3, 'S':4}
#lenght:13647309
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  df_train.at[_c, feature] = map[es]
  _c += 1
print_t(s_t)
print("finish")
#"""

# %%
feature = 'pais_residencia'
s_t = time.time()
"""
ind = {}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = _c
    _c += 1
print(ind)
"""
#"""
map = {'ES': 0, 'CA': 1, 'CH': 2, 'CL': 3, 'IE': 4, 'AT': 5,
 'NL': 6, 'FR': 7, 'GB': 8, 'DE': 9, 'DO': 10, 'BE': 11,
 'AR': 12, 'VE': 13, 'US': 14, 'MX': 15, 'BR': 16, 'IT': 17,
 'EC': 18, 'PE': 19, 'CO': 20, 'HN': 21, 'FI': 22, 'SE': 23,
 'AL': 24, 'PT': 25, 'MZ': 26, 'CN': 27, 'TW': 28, 'PL': 29,
 'IN': 30, 'CR': 31, 'NI': 32, 'HK': 33, 'AD': 34, 'CZ': 35,
 'AE': 36, 'MA': 37, 'GR': 38, 'PR': 39, 'RO': 40, 'IL': 41,
 'RU': 42, 'GT': 43, 'GA': 44, 'NO': 45, 'SN': 46, 'MR': 47,
 'UA': 48, 'BG': 49, 'PY': 50, 'EE': 51, 'SV': 52, 'ET': 53,
 'CM': 54, 'SA': 55, 'CI': 56, 'QA': 57, 'LU': 58, 'PA': 59,
 'BA': 60, 'BO': 61, 'AU': 62, 'BY': 63, 'KE': 64, 'SG': 65,
 'HR': 66, 'MD': 67, 'SK': 68, 'TR': 69, 'AO': 70, 'CU': 71,
 'GQ': 72, 'EG': 73, 'ZA': 74, 'DK': 75, 'UY': 76, 'GE': 77,
 'TH': 78, 'DZ': 79, 'LB': 80, 'JP': 81, 'NG': 82, 'PK': 83,
 'TN': 84, 'TG': 85, 'KR': 86, 'GH': 87, 'RS': 88, 'VN': 89,
 'PH': 90, 'KW': 91, 'NZ': 92, 'MM': 93, 'KH': 94, 'GI': 95,
 'SL': 96, 'GN': 97, 'GW': 98, 'OM': 99, 'CG': 100, 'LV': 101,
 'LT': 102, 'ML': 103, 'MK': 104, 'HU': 105, 'IS': 106, 'LY': 107,
 'CF': 108, 'GM': 109, 'KZ': 110, 'CD': 111, 'BZ': 112, 'ZW': 113,
 'DJ': 114, 'JM': 115, 'BM': 116, 'MT': 117}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  df_train.at[_c, feature] = map[es]
  _c += 1
print_t(s_t)
print("finish")
#"""
# Out:
# finish

# %%
feature = 'sexo'
s_t = time.time()
"""
ind = {}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = _c
    _c += 1
print(ind)
"""
#"""
map = {'H':0, 'V':1}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  df_train.at[_c, feature] = map[es]
  _c += 1
print_t(s_t)
print("finish")
#"""

# %%
feature = 'age'
s_t = time.time()

#"""
_c = 0
for e in df_train[feature]:
  es = e
  if (es >=100):
    df_train.at[_c, feature] = 100/100
  else:
    df_train.at[_c, feature] = es/100
  _c += 1
print_t(s_t)
print("finish")
#"""
"""
ind = {}
for e in df_train[feature]:
  if(e not in ind):
    ind[e] = 1
for e in ind:
  print(int(e))
"""
# Out:
# [0:04:37]
# finish
# '\nind = {}\nfor e in df_train[feature]:\n  if(e not in ind):\n    ind[e] = 1\nfor e in ind:\n  print(int(e))\n'

# %%
feature = 'fecha_alta'
s_t = time.time()
"""
_c = 0
fea = []
for e in df_train[feature]:
  es = str(e).strip()
  y = int(es[:4])
  m = int(es[5:7])
  d = int(es[-2:])
  _c += 1
  days = 365*(y-1995)+31*(m)+d
  fea.append(days)
fea = np.array(fea)
print(np.max(fea, axis=0)) #7851
print(np.min(fea, axis=0)) #47
"""
#"""
_c = 0
for e in df_train[feature]:
  y = int(e[:4])
  m = int(e[5:7])
  d = int(e[-2:])
  days = 365*(y-1995)+31*(m)+d
  days = days / 7851
  df_train.at[_c, feature] = days
  _c += 1
print_t(s_t)
print("finish")
#"""
# Out:
# [0:08:44]
# finish

# %%
feature = 'ind_nuevo'
s_t = time.time()
#"""
ind = {}
for e in df_train[feature]:
  if (float(e) not in ind):
    ind[e] = 1
print(ind)
#"""
#already 0 or 1, skip
# Out:
# {'0.0': 1, '1.0': 1}

# %%
feature = 'antiguedad'
s_t = time.time()
"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = 0
  ind[es] += 1
print(ind)
print(len(ind))
l = 0
_k = ''
mk = 0
for k in ind:
  if k != 'NA':
    if int(k) > int(mk):
      mk = k
  if ind[k] > l:
    l = ind[k]
    _k = k
print(_k, l)
print(mk) #max 256
"""
#"""
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  if (es == 'NA'):
    df_train.at[_c, feature] = 12/256
  else:
    df_train.at[_c, feature] = float(es)/256
  _c += 1
print_t(s_t)
print("finish")
#"""
# Out:
# [0:33:09]
# finish

# %%
feature = 'indrel'
s_t = time.time()
#"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = float(e)
  if (es not in ind):
    ind[es] = 0
  ind[es] += 1
print(ind)
#"""
#"""
_c = 0
for e in df_train[feature]:
  es = float(e)
  df_train.at[_c, feature] = es/100
  _c += 1
print_t(s_t)
print("finish")
#"""
# Out:
# {1.0: 13622516, 99.0: 24793}
# [0:19:39]
# finish

# %%
#drop ult_fec_cli_1t

# %%
feature = 'indrel_1mes'
s_t = time.time()
"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = 0
  ind[es] += 1
print(ind)
"""
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  if es == 'P':
    df_train.at[_c, feature] = 0
  else:
    df_train.at[_c, feature] = int(float(es)-1)
  _c += 1
print_t(s_t)
print("finish")

# %%
feature = 'tiprel_1mes'
s_t = time.time()
"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = 0
  ind[es] += 1
print(ind)
"""
#"""
map = {'A': 0, 'I': 1, 'P': 2, 'R': 3, 'N': 0}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  df_train.at[_c, feature] = map[es]
  _c += 1
#"""
print_t(s_t)
print("finish")

# %%
feature = 'indresi'
s_t = time.time()
"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = 0
  ind[es] += 1
print(ind)
"""
#"""
map = {'S': 0, 'N': 1}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  df_train.at[_c, feature] = map[es]
  _c += 1
#"""
print_t(s_t)
print("finish")

# %%
feature = 'indext'
s_t = time.time()
"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = 0
  ind[es] += 1
print(ind)
"""
#"""
map = {'S': 0, 'N': 1}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  df_train.at[_c, feature] = map[es]
  _c += 1
#"""
print_t(s_t)
print("finish")

# %%
feature = 'conyuemp'
#s_t = time.time()
#print_t(s_t)
#print("finish")
#drop

# %%
feature = 'canal_entrada'
s_t = time.time()
"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = _c
    _c += 1
print(ind)
print(len(ind))
"""
#"""
map = {'KHL': 0, 'KHE': 1, 'KHD': 2, 'KFA': 3, 'KFC': 4, 'KAT': 5, 'KAZ': 6, 'RED': 7,
'KHC': 8, 'KHK': 9, 'KGN': 10, 'KHM': 11, 'KHO': 12, 'KDH': 13, 'KEH': 14, 'KAD': 15,
'KBG': 16, 'KGC': 17, 'KHF': 18, 'KFK': 19, 'KHN': 20, 'KHA': 21, 'KAF': 22, 'KGX': 23,
'KFD': 24, 'KAG': 25, 'KFG': 26, 'KAB': 27, 'KCC': 28, 'KAE': 29, 'KAH': 30, 'KAR': 31,
'KFJ': 32, 'KFL': 33, 'KAI': 34, 'KFU': 35, 'KAQ': 36, 'KFS': 37, 'KAA': 38, 'KFP': 39,
'KAJ': 40, 'KFN': 41, 'KGV': 42, 'KGY': 43, 'KFF': 44, 'KAP': 45, 'KDE': 46, 'KFV': 47,
'013': 48, 'K00': 49, 'KAK': 50, 'KCK': 51, 'KCL': 52, 'KAY': 53, 'KBU': 54, 'KDR': 55,
'KAC': 56, 'KDT': 57, 'KCG': 58, 'KDO': 59, 'KDY': 60, 'KBQ': 61, 'KDA': 62, 'KBO': 63,
'KCI': 64, 'KEC': 65, 'KBZ': 66, 'KES': 67, 'KDX': 68, 'KAS': 69, '007': 70, 'KEU': 71,
'KCA': 72, 'KAL': 73, 'KDC': 74, 'KAW': 75, 'KCS': 76, 'KCB': 77, 'KDU': 78, 'KDQ': 79,
'KCN': 80, 'KCM': 81, '004': 82, 'KCH': 83, 'KCD': 84, 'KCE': 85, 'KEV': 86, 'KBL': 87,
'KEA': 88, 'KBH': 89, 'KDV': 90, 'KFT': 91, 'KEY': 92, 'KAO': 93, 'KEJ': 94, 'KEO': 95,
'KEI': 96, 'KEW': 97, 'KDZ': 98, 'KBV': 99, 'KBR': 100, 'KBF': 101, 'KDP': 102, 'KCO': 103,
'KCF': 104, 'KCV': 105, 'KAM': 106, 'KEZ': 107, 'KBD': 108, 'KAN': 109, 'KBY': 110, 'KCT': 111,
'KDD': 112, 'KBW': 113, 'KCU': 114, 'KBX': 115, 'KDB': 116, 'KBS': 117, 'KBE': 118, 'KCX': 119,
'KBP': 120, 'KBN': 121, 'KEB': 122, 'KDS': 123, 'KEL': 124, 'KDG': 125, 'KDF': 126, 'KEF': 127,
'KCP': 128, 'KDM': 129, 'KBB': 130, 'KDW': 131, 'KBJ': 132, 'KFI': 133, 'KBM': 134, 'KEG': 135,
'KEN': 136, 'KEQ': 137, 'KAV': 138, 'KFH': 139, 'KFM': 140, 'KAU': 141, 'KED': 142, 'KFR': 143,
'KEK': 144, 'KFB': 145, 'KGW': 146, 'KFE': 147, 'KGU': 148, 'KDI': 149, 'KDN': 150, 'KEE': 151,
'KCR': 152, 'KCQ': 153, 'KEM': 154, 'KCJ': 155, 'KHQ': 156, 'KDL': 157, '025': 158, 'KHP': 159,
'KHR': 160, 'KHS': 161}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  df_train.at[_c, feature] = map[es]
  _c += 1
#"""
print_t(s_t)
print("finish")
# Out:
# [0:04:02]
# finish

# %%
feature = 'indfall'
s_t = time.time()
"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = _c
    _c += 1
print(ind)
print(len(ind))
"""
#"""
map = {'S': 0, 'N': 1}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  df_train.at[_c, feature] = map[es]
  _c += 1
#"""
print_t(s_t)
print("finish")

# %%
#feature = 'tipodom'
#s_t = time.time()
#print_t(s_t)
#print("finish")
#drop
# Out:
# {'1.0': 13647309}
# 1
# [0:00:08]
# finish

# %%
feature = 'cod_prov'
s_t = time.time()
"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = _c
    _c += 1
print(ind)
print(len(ind))
"""
#"""
map = {'29.0': 0, '13.0': 1, '50.0': 2, '45.0': 3, '24.0': 4, '20.0': 5, '10.0': 6,
'17.0': 7, '49.0': 8, '8.0': 9, '37.0': 10, '9.0': 11, '22.0': 12, '31.0': 13,
'5.0': 14, '40.0': 15, '27.0': 16, '25.0': 17, '28.0': 18, '3.0': 19, '42.0': 20,
'41.0': 21, '39.0': 22, '7.0': 23, '47.0': 24, '36.0': 25, '46.0': 26, '44.0': 27,
'15.0': 28, '32.0': 29, '23.0': 30, '16.0': 31, '48.0': 32, '12.0': 33, '26.0': 34,
'2.0': 35, '6.0': 36, '30.0': 37, '11.0': 38, '4.0': 39, '19.0': 40, '34.0': 41,
'35.0': 42, '14.0': 43, '21.0': 44, '18.0': 45, '33.0': 46, '38.0': 47, '52.0': 48,
'43.0': 49, '1.0': 50, '51.0': 51}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  df_train.at[_c, feature] = map[es]
  _c += 1
#"""
print_t(s_t)
print("finish")
# Out:
# [0:04:23]
# finish

# %%
#feature = 'nomprov'
#s_t = time.time()
#print_t(s_t)
#print("finish")
#drop

# %%
feature = 'ind_actividad_cliente'
s_t = time.time()
"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = _c
    _c += 1
print(ind)
print(len(ind))
"""
print_t(s_t)
print("finish")
#skip

# %%
feature = 'renta'
s_t = time.time()
"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = _c
    _c += 1
print(ind)
print(len(ind))
"""
#"""
_c = 0
for e in df_train[feature]:
  es = float(str(e).strip())
  if es >= 28894395/100:
    es = 28894395/100
  df_train.at[_c, feature] = es / (28894395/100)
  _c += 1
#"""
print_t(s_t)
print("finish")
# Out:
# [0:04:26]
# finish

# %%
feature = 'segmento'
s_t = time.time()
"""
_c = 0
fea = []
ind = {}
for e in df_train[feature]:
  es = str(e).strip()
  if (es not in ind):
    ind[es] = _c
    _c += 1
print(ind)
print(len(ind))
"""
#"""
map = {'02 - PARTICULARES': 0, '03 - UNIVERSITARIO': 1, '01 - TOP': 2}
_c = 0
for e in df_train[feature]:
  es = str(e).strip()
  df_train.at[_c, feature] = map[es]
  _c += 1
#"""
print_t(s_t)
print("finish")
# Out:
# [0:04:10]
# finish

# %%
s_t = time.time()
df_train.to_csv("./data/processed/ver1_2.csv", index=False)
print_t(s_t)
# Out:
# [0:03:48]

# %%
#process end

# %%
#test area

# %%
df_train.iloc[0]
#df_train.size

# %%
#显示所有列
pd.set_option('display.max_columns', None)
#显示所有行
pd.set_option('display.max_rows', None)
#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)
filter = (df_train['ncodpers'] == 255397)
df_train[filter]

# %%
from matplotlib import pyplot as plt
import time

start_t = time.time()
age = [0 for _ in range(200)]
x = [_ for _ in range(200)]
NA_count = 0
for i in df_train['age']:
  if (str(i).strip() == 'NA'):
    NA_count += 1
  else:
    age[int(i)] += 1
print(age)
plt.figure()
plt.plot(x, age)
plt.show()
_print("", start_t)
print(NA_count)

# %%
import pandas as pd
df = pd.read_csv("./data/sample_submission.csv")

# %%
df
